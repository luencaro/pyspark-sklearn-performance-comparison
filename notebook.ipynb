# %% [markdown]
# # **Imports**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load datasets
data_acc = pd.read_csv('Data/accepted_2007_to_2018Q4.csv', low_memory=False)
data_rej = pd.read_csv('Data/rejected_2007_to_2018Q4.csv', low_memory=False)

# %% [markdown]
# # **Exploración de datos (EDA)**

# %%
data_acc.head()
print("\n ======================================")
data_rej.head()

# %% [markdown]
# # **Preprocesamiento**

# %% [markdown]
# ## **scikit-learn**

# %% [markdown]
# ## **PySpark**

# %% [markdown]
# # **Modelado**

# %% [markdown]
# ## **Modelado con scikit-learn**

# %% [markdown]
# ## **Modelado con PySpark**

# %% [markdown]
# ## **Evaluación de métricas**

# %% [markdown]
# # **Interpretabilidad con LIME**
